# %% [markdown]
# <a href="https://colab.research.google.com/github/dipucriodigital/ciencia-de-dados-e-analytics/blob/main/analytics-descriptive-and-predictive/Aula%2001%20-%20Introducao%20Redes%20Neurais.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>

# %% [markdown]
# ## Exemplo de um Perceptron

# %% [markdown]
# Para este exemplo, vamos criar um dataset que simula a não linearidade da operação XOR. Para isto, criaremos quatro grupos distintos de dados.

# %%
# Criando o dataset XOR

import numpy as np                          # carrega a biblioteca numpy para operações matriciais

from sklearn.preprocessing import StandardScaler  # importa o método Standard Scaler para a normalização (escalamento) dos dados
from sklearn.utils import shuffle    # metodo shuffle vai embaralhar os pontos gerados

np.random.seed(1000)   # define a seed do random para que o experimento possa ser reproduzido

nb_samples = 1000              #serão criados 1000 pontos
nsb = int(nb_samples / 4)      #divididos em 4 grupos
X = np.zeros((nb_samples, 2))  #onde aqui definimos o tamanho do conjunto X (pontos) - 1000 pontos com 2 dimensões (coordenadas)
Y = np.zeros((nb_samples, ))   #e do Y (classes conjunto roxo = 1 ou conjunto amarelo = 0)

#vamos definir a pequena variação entre os pontos de cada conjunto
#coordenada 1, -1
X[0:nsb, :] = np.random.multivariate_normal([1.0, -1.0], np.diag([0.1, 0.1]), size=nsb)
Y[0:nsb] = 0.0 # classe 0

#coordenada 1, 1
X[nsb:(2 * nsb), :] = np.random.multivariate_normal([1.0, 1.0], np.diag([0.1, 0.1]), size=nsb)
Y[nsb:(2 * nsb)] = 1.0 #classe 1

#coordenada -1, 1
X[(2 * nsb):(3 * nsb), :] = np.random.multivariate_normal([-1.0, 1.0], np.diag([0.1, 0.1]), size=nsb)
Y[(2 * nsb):(3 * nsb)] = 0.0 #classe 0

#coordenada -1, -1
X[(3 * nsb):, :] = np.random.multivariate_normal([-1.0, -1.0], np.diag([0.1, 0.1]), size=nsb)
Y[(3 * nsb):] = 1.0 #classe 1

ss = StandardScaler()
X = ss.fit_transform(X) #normaliza os dados para a escala entre 0,1

X, Y = shuffle(X, Y, random_state=1000) # embaralha os dados

# %%
#Exibindo dataset XOR
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.show()

# %% [markdown]
# ### Vamos verificar a acurácia usando um perceptron?

# %%
import numpy as np # carrega o numpy

from multiprocessing import cpu_count  #cpu_count define quantos núcles tem o computador - para usar paralelismo durante a execução do algoritmo

from sklearn.linear_model import Perceptron  #importa o modelo perceptron
from sklearn.model_selection import cross_val_score #utiliza o método cross validation para indicar a acurácia média do modelo

pc = Perceptron(penalty='l2', alpha=0.1, max_iter=1000, n_jobs=cpu_count(), random_state=1000) # carrega o perceptron
print(np.mean(cross_val_score(pc, X, Y, cv=10))) # exibe o a acuracia média encontrada pelo modelo
# Out:
# 0.5039999999999999

# %% [markdown]
# ### Como o perceptron separa as regiões?

# %%
#Funções para plotar a superficie (regiões)
#para demonstrar separação pelo modelo criado

import numpy as np
import matplotlib.pyplot as plt

def make_meshgrid(x, y, h=.02):
    #define a grade para as coordenadas do gráfico
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

def plot_contours(ax, clf, xx, yy, **params):
    #executa a classificação usando o modelo carregado em clf
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

def plot_model(clf):
    fig, ax = plt.subplots()
    # titulo do gráfico
    title = ('Superfície de Decisão')
    # configura as cooredenadas para plotar o gráfico
    X0, X1 = X[:, 0], X[:, 1]
    xx, yy = make_meshgrid(X0, X1)

    #chama a funcao pra definir os valores do modelo
    plot_contours(ax, clf, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_title(title)
    plt.show()

# %%
pc.fit(X, Y) # realiza o aprendizado do modelo carregado em pc
plot_model(pc) # as funções acima para executar a classificação e exibir a linha de separaçao dos resultados

# %% [markdown]
# ## MLP - Multilayer Perceptrons

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential() # carrega um modelo feed-forward

model.add(Dense(4, input_dim=2)) #cria uma camada densa com com 4 neuronios e 2 entradas
model.add(Activation('tanh'))   #usando função de ativação tangente hiperbólica

model.add(Dense(2))  #cria uma camada densa com com 2 neuronios (que recebe as saídas da camada anterior)
model.add(Activation('softmax'))   #usando função de ativação softmax para definir qual é a classe na saída

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']) # define a rede neural
# Out:
# 2025-08-23 17:53:31.781105: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-23 17:53:31.788398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-23 17:53:31.798407: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-23 17:53:31.798418: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-23 17:53:31.805190: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-23 17:53:32.266689: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jonatas/project/ciencia-de-dados-e-analytics/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-23 17:53:32.536168: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2025-08-23 17:53:32.536180: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:134] retrieving CUDA diagnostic information for host: ubuntu
# 2025-08-23 17:53:32.536182: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:141] hostname: ubuntu
# 2025-08-23 17:53:32.536252: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:165] libcuda reported version is: 535.230.2
# 2025-08-23 17:53:32.536259: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:169] kernel reported version is: 535.216.3
# 2025-08-23 17:53:32.536261: E external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:251] kernel version 535.216.3 does not match DSO version 535.230.2 -- cannot find working devices in this configuration

# %%
#vamos separar o conjunto de treinamento e de testes
#30% para testes, o restante para treinamento

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1000) # separa o conjunto de teste com 30% dos dados sorteados aleatóriamente com seed = 1000 
#outros 70% são definidos no conjunto de teste

# %%
#treinamento da rede neural 
#usando 100 épocas

#método fit executa o treinamento
model.fit(X_train,  #para o conjunto de teste "train" onde x_train sao os atributos
          to_categorical(Y_train, num_classes=2),  #e y_train sao as classes
          epochs=100,  #em 100 épocas
          batch_size=32, #de 32 em 32
          validation_data=(X_test, to_categorical(Y_test, num_classes=2))) # e demonstrando a acurácia de teste com o conjunto "X_test e Y_test"
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9988 - loss: 0.1112 - val_accuracy: 1.0000 - val_loss: 0.1119
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.1167 - val_accuracy: 1.0000 - val_loss: 0.1084
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.9994 - loss: 0.1094 - val_accuracy: 1.0000 - val_loss: 0.1051
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.9993 - loss: 0.1072 - val_accuracy: 1.0000 - val_loss: 0.1020
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9986 - loss: 0.1015 - val_accuracy: 1.0000 - val_loss: 0.0991
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9983 - loss: 0.0991 - val_accuracy: 1.0000 - val_loss: 0.0963
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9984 - loss: 0.0938 - val_accuracy: 1.0000 - val_loss: 0.0935
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0974 - val_accuracy: 1.0000 - val_loss: 0.0910
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 1.0000 - val_loss: 0.0884
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 1.0000 - loss: 0.0918 - val_accuracy: 1.0000 - val_loss: 0.0860
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0907 - val_accuracy: 1.0000 - val_loss: 0.0838
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0845 - val_accuracy: 1.0000 - val_loss: 0.0815
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 1.0000 - loss: 0.0796 - val_accuracy: 1.0000 - val_loss: 0.0795
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 1.0000 - loss: 0.0787 - val_accuracy: 1.0000 - val_loss: 0.0775
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0737 - val_accuracy: 1.0000 - val_loss: 0.0756
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0737 - val_accuracy: 1.0000 - val_loss: 0.0738
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 1.0000 - val_loss: 0.0719
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 1.0000 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0703
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0698 - val_accuracy: 1.0000 - val_loss: 0.0686
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 1.0000 - loss: 0.0715 - val_accuracy: 1.0000 - val_loss: 0.0670
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 1.0000 - loss: 0.0668 - val_accuracy: 1.0000 - val_loss: 0.0655
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 1.0000 - val_loss: 0.0641
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0627
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 1.0000 - val_loss: 0.0614
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0615 - val_accuracy: 1.0000 - val_loss: 0.0600
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0623 - val_accuracy: 1.0000 - val_loss: 0.0587
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0568 - val_accuracy: 1.0000 - val_loss: 0.0575
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0565 - val_accuracy: 1.0000 - val_loss: 0.0564
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0601 - val_accuracy: 1.0000 - val_loss: 0.0552
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0565 - val_accuracy: 1.0000 - val_loss: 0.0541
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0510 - val_accuracy: 1.0000 - val_loss: 0.0531
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0512 - val_accuracy: 1.0000 - val_loss: 0.0520
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 1.0000 - loss: 0.0524 - val_accuracy: 1.0000 - val_loss: 0.0511
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0569 - val_accuracy: 1.0000 - val_loss: 0.0501
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0507 - val_accuracy: 1.0000 - val_loss: 0.0491
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0488 - val_accuracy: 1.0000 - val_loss: 0.0483
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0474
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0465 - val_accuracy: 1.0000 - val_loss: 0.0465
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 0.0458
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0449
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0411 - val_accuracy: 1.0000 - val_loss: 0.0441
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0415 - val_accuracy: 1.0000 - val_loss: 0.0433

# %%
#verificação(predição) usando a base de teste
#qual seria a resposta da rede treinada se ela classificar os pontos que estao no conjunto de testes?

Y_eval_mlp = np.argmax(model.predict(X_test), axis=1) #retorna as classes definidas pelo modelo
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %% [markdown]
# ### Superficie usando o modelo atual com tanh

# %%
#para verificarmos os limites entre os conjuntos de classificação
#vamos criar um conjunto com muitos pontos gerados aleatóriamente
#e usar o modelo para definir qual seria sua classe

import numpy as np

Xm = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada X
Ym = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada Y
Xmg, Ymg = np.meshgrid(Xm, Ym)  #retorna as coordenadas da grade 2-D com base nas coordenadas contidas nos vetores x e y
X_eval = np.vstack([Xmg.ravel(), Ymg.ravel()]).T #cria o conjunto de entradas para as coordenadas geradas

Y_eval_mlp = np.argmax(model.predict(X_eval), axis=1) # usa o modelo carregado em model para realizar a classificação
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 13s 426us/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_eval[:, 0], X_eval[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %% [markdown]
# ### E se criarmos um modelo usando função de ativação Relu?

# %%
#para isto, vamos reproduzir a mesma rede neural anterior
#mas mudando a função de ativação

model = Sequential() # carrega um modelo feed-forward

model.add(Dense(4, input_dim=2)) #cria uma camada densa com com 4 neuronios e 2 entradas
model.add(Activation('relu'))   #usando função de ativação relu

model.add(Dense(2))  #cria uma camada densa com com 2 neuronios (que recebe as saídas da camada anterior)
model.add(Activation('softmax'))   #usando função de ativação softmax para definir qual é a classe na saída

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']) # define a rede neural

# %%
#vamos separar o conjunto de treinamento e de testes
#30% para testes, o restante para treinamento

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1000) # separa o conjunto de teste com 30% dos dados sorteados aleatóriamente com seed = 1000 
#outros 70% são definidos no conjunto de teste

#treinamento da rede neural 
#usando 100 épocas

#método fit executa o treinamento
model.fit(X_train,  #para o conjunto de teste "train" onde x_train sao os atributos
          to_categorical(Y_train, num_classes=2),  #e y_train sao as classes
          epochs=100,  #em 100 épocas
          batch_size=32, #de 32 em 32
          validation_data=(X_test, to_categorical(Y_test, num_classes=2))) # e demonstrando a acurácia de teste com o conjunto "X_test e Y_test"
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5936 - loss: 0.7662 - val_accuracy: 0.5833 - val_loss: 0.7391
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5518 - loss: 0.7555 - val_accuracy: 0.5200 - val_loss: 0.7198
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5395 - loss: 0.7162 - val_accuracy: 0.4700 - val_loss: 0.7036
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4964 - loss: 0.7016 - val_accuracy: 0.4600 - val_loss: 0.6893
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5099 - loss: 0.6765 - val_accuracy: 0.4867 - val_loss: 0.6768
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5543 - loss: 0.6590 - val_accuracy: 0.5667 - val_loss: 0.6645
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.6208 - loss: 0.6494 - val_accuracy: 0.6067 - val_loss: 0.6531
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.6952 - loss: 0.6338 - val_accuracy: 0.6267 - val_loss: 0.6417
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7066 - loss: 0.6208 - val_accuracy: 0.6400 - val_loss: 0.6298
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.7203 - loss: 0.6056 - val_accuracy: 0.6433 - val_loss: 0.6178
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.7184 - loss: 0.5963 - val_accuracy: 0.6567 - val_loss: 0.6057
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.7100 - loss: 0.5878 - val_accuracy: 0.6567 - val_loss: 0.5941
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7157 - loss: 0.5750 - val_accuracy: 0.6567 - val_loss: 0.5821
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7327 - loss: 0.5494 - val_accuracy: 0.6567 - val_loss: 0.5709
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7107 - loss: 0.5466 - val_accuracy: 0.6600 - val_loss: 0.5599
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7531 - loss: 0.5180 - val_accuracy: 0.6600 - val_loss: 0.5493
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7559 - loss: 0.5094 - val_accuracy: 0.6600 - val_loss: 0.5396
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.7511 - loss: 0.4946 - val_accuracy: 0.6600 - val_loss: 0.5297
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7556 - loss: 0.4863 - val_accuracy: 0.6600 - val_loss: 0.5205
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7372 - loss: 0.4851 - val_accuracy: 0.6633 - val_loss: 0.5117
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7561 - loss: 0.4690 - val_accuracy: 0.6667 - val_loss: 0.5034
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.7373 - loss: 0.4642 - val_accuracy: 0.6667 - val_loss: 0.4945
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.7574 - loss: 0.4508 - val_accuracy: 0.6667 - val_loss: 0.4865
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.7607 - loss: 0.4404 - val_accuracy: 0.6767 - val_loss: 0.4782
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7728 - loss: 0.4419 - val_accuracy: 0.6933 - val_loss: 0.4701
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7726 - loss: 0.4231 - val_accuracy: 0.7267 - val_loss: 0.4613
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s
100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9901 - loss: 0.1765 - val_accuracy: 0.9867 - val_loss: 0.1847
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9872 - loss: 0.1773 - val_accuracy: 0.9867 - val_loss: 0.1795
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9871 - loss: 0.1728 - val_accuracy: 0.9867 - val_loss: 0.1748
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9895 - loss: 0.1617 - val_accuracy: 0.9867 - val_loss: 0.1699
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.1552 - val_accuracy: 0.9867 - val_loss: 0.1652
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.1590 - val_accuracy: 0.9867 - val_loss: 0.1606
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9947 - loss: 0.1408 - val_accuracy: 0.9867 - val_loss: 0.1567
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9833 - loss: 0.1470 - val_accuracy: 0.9867 - val_loss: 0.1525
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9927 - loss: 0.1395 - val_accuracy: 0.9867 - val_loss: 0.1485
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9894 - loss: 0.1395 - val_accuracy: 0.9867 - val_loss: 0.1450
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9930 - loss: 0.1290 - val_accuracy: 0.9867 - val_loss: 0.1411
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9917 - loss: 0.1313 - val_accuracy: 0.9867 - val_loss: 0.1378
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.9903 - loss: 0.1236 - val_accuracy: 0.9867 - val_loss: 0.1348
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.1226 - val_accuracy: 0.9867 - val_loss: 0.1311
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.9949 - loss: 0.1150 - val_accuracy: 0.9867 - val_loss: 0.1281
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.1245 - val_accuracy: 0.9867 - val_loss: 0.1252
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9880 - loss: 0.1235 - val_accuracy: 0.9867 - val_loss: 0.1221
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9960 - loss: 0.1147 - val_accuracy: 0.9867 - val_loss: 0.1192
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9872 - loss: 0.1241 - val_accuracy: 0.9867 - val_loss: 0.1169
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.1090 - val_accuracy: 0.9867 - val_loss: 0.1143
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9895 - loss: 0.1066 - val_accuracy: 0.9867 - val_loss: 0.1117
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.1022 - val_accuracy: 0.9867 - val_loss: 0.1093
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9906 - loss: 0.1079 - val_accuracy: 0.9867 - val_loss: 0.1071
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9860 - loss: 0.1058 - val_accuracy: 0.9867 - val_loss: 0.1049
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9865 - loss: 0.1015 - val_accuracy: 0.9867 - val_loss: 0.1027
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9921 - loss: 0.0915 - val_accuracy: 0.9867 - val_loss: 0.1007
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.9915 - loss: 0.0980 - val_accuracy: 0.9867 - val_loss: 0.0988
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.0931 - val_accuracy: 0.9900 - val_loss: 0.0966
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9960 - loss: 0.0860 - val_accuracy: 0.9900 - val_loss: 0.0948
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.9939 - loss: 0.0922 - val_accuracy: 0.9900 - val_loss: 0.0928
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0831 - val_accuracy: 0.9900 - val_loss: 0.0911
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9907 - loss: 0.0815 - val_accuracy: 0.9900 - val_loss: 0.0894
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9832 - loss: 0.0934 - val_accuracy: 0.9900 - val_loss: 0.0876
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.9963 - loss: 0.0769 - val_accuracy: 0.9900 - val_loss: 0.0861
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0769 - val_accuracy: 0.9900 - val_loss: 0.0845
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.9872 - loss: 0.0796 - val_accuracy: 0.9900 - val_loss: 0.0830
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9940 - loss: 0.0791 - val_accuracy: 0.9900 - val_loss: 0.0815
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9960 - loss: 0.0723 - val_accuracy: 0.9900 - val_loss: 0.0800
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0737 - val_accuracy: 0.9900 - val_loss: 0.0787
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0716 - val_accuracy: 0.9900 - val_loss: 0.0774
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.9932 - loss: 0.0672 - val_accuracy: 0.9900 - val_loss: 0.0757
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.0709 - val_accuracy: 0.9900 - val_loss: 0.0744
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0687 - val_accuracy: 0.9900 - val_loss: 0.0735
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.0638 - val_accuracy: 0.9900 - val_loss: 0.0723
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0623 - val_accuracy: 0.9900 - val_loss: 0.0710

# %%
#verificação(predição) usando a base de teste
#qual seria a resposta da rede treinada se ela classificar os pontos que estao no conjunto de testes?

Y_eval_mlp = np.argmax(model.predict(X_test), axis=1) #retorna as classes definidas pelo modelo
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %%
#para verificarmos os limites entre os conjuntos de classificação
#vamos criar um conjunto com muitos pontos gerados aleatóriamente
#e usar o modelo para definir qual seria sua classe

import numpy as np

Xm = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada X
Ym = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada Y
Xmg, Ymg = np.meshgrid(Xm, Ym)  #retorna as coordenadas da grade 2-D com base nas coordenadas contidas nos vetores x e y
X_eval = np.vstack([Xmg.ravel(), Ymg.ravel()]).T #cria o conjunto de entradas para as coordenadas geradas

Y_eval_mlp = np.argmax(model.predict(X_eval), axis=1) # usa o modelo carregado em model para realizar a classificação
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 13s 417us/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_eval[:, 0], X_eval[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico
